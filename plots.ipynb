# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## MergeSmall_k

# %%
sizes = [16, 32, 64, 128, 256, 512, 1024]
#Average execution times in microseconds (Average over 1000000 runs)
exec_times = [4, 5, 5, 6, 7, 8, 9]

# %%
plt.figure(figsize=[10,5])
plt.plot(sizes, exec_times)
plt.title("Temps d'exécution de MergeSmall_k")
plt.xlabel("|A|+|B|")
plt.ylabel("Temps d'exécution")
plt.show()

# %% [markdown]
# ## MergeSmallBatch_k

# %%
sizes = [4, 8, 16, 32, 64, 128, 256, 512, 1024]
#Average execution times in microseconds (Average over 100000 runs)
exec_times = [6, 7, 8, 9, 10, 12, 14, 15, 18]

# %%
plt.figure(figsize=[10,5])
plt.plot(sizes, exec_times)
plt.title("Temps d'exécution de MergeSmallBatch_k")
plt.xlabel("d")
plt.ylabel("Temps d'exécution")
plt.show()

# %% [markdown]
# ## SortSmall_k

# %%
sizes = [4, 8, 16, 32, 64, 128, 256, 512, 1024]
sizes = np.log2(sizes)
#Average execution times in microseconds (Average over 100000 runs)
exec_times = [0.000031, 0.000053, 0.000084, 0.000125, 0.000168, 0.000284, 0.000559, 0.001220, 0.003040]

# %%
plt.figure(figsize=[10,5])
plt.plot(sizes, exec_times)
plt.title("Temps d'exécution de SortSmall")
plt.xlabel("sub_arrays size")
plt.ylabel("Temps d'exécution")
plt.show()

# %% [markdown]
# ## GlobalMerge

# %%
sizes = [1024, 2048, 3072, 4096]
#Average execution times in microseconds (Average over 100000 runs)
exec_times = [11, 14, 16, 22]

# %%
plt.figure(figsize=[10,5])
plt.plot(sizes, exec_times)
plt.title("Temps d'exécution de Global Merge")
plt.xlabel("|A|+|B|")
plt.ylabel("Temps d'exécution")
plt.show()

# %% [markdown]
# ## Merge Sort

# %%
sizes = np.array([4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096, 8192, 16384, 32768, 65536, 131072, 262144])
#Average execution times in seconds (Average over 1000 runs)
exec_times_32 = [0.000354, 0.000345, 0.000346, 0.000370, 0.000404, 0.000450, 0.000525, 0.000677, 0.000964, 0.001537, 0.002688, 0.004910, 0.009262, 0.018029, 0.035752, 0.073637, 0.150138]
exec_times_64 = [0.000367, 0.000339, 0.000348, 0.000373, 0.000383, 0.000417, 0.000467, 0.000545, 0.000689, 0.000976, 0.001542, 0.002738, 0.004996, 0.009408, 0.018368, 0.036576, 0.074577]
exec_times_128 = [0.000354, 0.000368, 0.000355, 0.000353, 0.000367, 0.000407, 0.000420, 0.000469, 0.000540, 0.000691, 0.000957, 0.001526, 0.002738, 0.004986, 0.009495, 0.018470, 0.036571]
exec_times_256 = [0.000366, 0.000354, 0.000349, 0.000361, 0.000377, 0.000392, 0.000403, 0.000465, 0.000503, 0.000576, 0.000715, 0.001009, 0.001608, 0.002886, 0.005390, 0.010195, 0.019883]
exec_times_512 = [0.000371, 0.000347, 0.000347, 0.000352, 0.000373, 0.000414, 0.000415, 0.000444, 0.000478, 0.000535, 0.000602, 0.000766, 0.001106, 0.001819, 0.003377, 0.006181, 0.011907]
exec_times_1024 = [0.000361, 0.000346, 0.000342, 0.000365, 0.000380, 0.000394, 0.000427, 0.000429, 0.000467, 0.000510, 0.000572, 0.000678, 0.000856, 0.001298, 0.002322, 0.004215, 0.007889]

exec_times_quicksort = [0.000003, 0.000002, 0.000002, 0.000003, 0.000006, 0.0000012, 0.000026, 0.000063, 0.000094, 0.000188, 0.000439, 0.000955, 0.001915, 0.004311, 0.009280, 0.019359, 0.040253]

# %%
plt.figure(figsize=[10,5])
#sizes = np.log2(sizes)
f_display = plt.loglog
f_display(sizes, exec_times_32, label="sub-arrays size : 32")
f_display(sizes, exec_times_64)
f_display(sizes, exec_times_128)
f_display(sizes, exec_times_256)
f_display(sizes, exec_times_512)
f_display(sizes, exec_times_1024, label="sub-arrays size : 1024")
f_display(sizes, exec_times_quicksort, '+', label="Quicksort")
plt.legend()
plt.title("Temps d'exécution de Merge Sort")
plt.xlabel("d")
plt.ylabel("Temps d'exécution")
plt.show()
