# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## MergeSmall_k

# %%
sizes = [16, 32, 64, 128, 256, 512, 1024]
#Average execution times in microseconds (Average over 10000 runs)
exec_times = [4, 5, 5, 6, 7, 8, 9]

# %%
plt.figure(figsize=[10,5])
plt.plot(sizes, exec_times)
plt.title("Évolution du temps d'exécution en fonction de |A|+|B|")
plt.xlabel("|A|+|B|")
plt.ylabel("Temps d'exécution")
plt.show()
